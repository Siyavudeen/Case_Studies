# %% [markdown]
# # Aerofit - Descriptive Statistics & Probability

# %% [markdown]
# # About Aerofit
# Aerofit is a leading brand in the field of fitness equipment. Aerofit provides a
# product range including machines such as treadmills, exercise bikes, gym
# equipment, and fitness accessories to cater to the needs of all categories of
# people.

# %% [markdown]
# # Business Problem
# The market research team at AeroFit wants to identify the characteristics of
# the target audience for each type of treadmill offered by the company, to
# provide a better recommendation of the treadmills to the new customers. The
# team decides to investigate whether there are differences across the product
# with respect to customer characteristics.
# 1. Perform descriptive analytics to create a customer profile for each
# AeroFit treadmill product by developing appropriate tables and charts.
# 2. For each AeroFit treadmill product, construct two-way contingency
# tables and compute all conditional and marginal
# probabilities along with their insights/impact on the business.

# %% [markdown]
# # DESCRIPTION
#
# - ### Product - Product purchased:KP281, KP481, KP781.
# - ### Gender - Gender.
# - ### Age - Age (in years).
# - ### Education - Education (in years).
# - ### MaritalStatus - Relationship status: single or partnered
# - ### Income - Annual household income.
# - ### Usage - Average number of times the customer plans to use the treadmill each week.
# - ### Miles - Average number of miles the customer expects to walk/run each week.
# - ### Fitness - Self-rated fitness on an 1-to-5 scale, where 1 is poor shape and 5 is excellent shape.

# %% [markdown]
# # TASKS
# - ### Perform descriptive analytics to create a customer profile for each aerofit treadmill product line.
# - ### Identify the profile of the typical customer for each treadmill product offered by aerofit.
# - ### Investigate whether there are differences across the product lines with respect to customer characteristics.

# %% [markdown]
# # Problem Statements
# - ## Including Product_price to the dataset
# - ## KDE Plot of Age vs Fitness
# - ## Pie chart of Product Sales
# - ## Pie chart of Gender
# - ## Pie chart of MaritalStatus
# - ## Understanding the distribution of the data for the quantitative attributes
# - ## Outliers detection using BoxPlots
# - ### Outliers detection for Age
# - ### Outliers detection for Education
# - ### Outliers detection for Usage
# - ### Outliers detection for Fitness
# - ### Outliers detection for Income
# - ### Outliers detection for Miles
# - ## Outlier handling for income
# - ### Boxplot for income before removing outlier
# - ### Boxplot for income after removing outlier
# - ### Boxplot for Gender and the Income of customers purchasing products before outlier removal
# - ### Boxplot for Gender and the Income of customers purchasing products after outlier removal
# - ### Mean before removing outlier values
# - ### Mean after outlier removal
# - ## Outlier handling for Miles
# - ### Boxplot for Miles before removing outlier
# - ### Boxplot for Miles after removing outlier
# - ### Boxplot for Gender and the Miles of customers purchasing products before outlier removal
# - ### Boxplot for Gender and the Miles of customers purchasing products after outlier removal
# - ### Mean before outlier removal
# - ### Mean after outlier removal
# - ## EDA - Bivariate Analysis
# - ## Product counts
# - ## Gender Counts
# - ## MaritalStatus Counts
# - ## Variable counts
# - # Bivariate Analysis
# - ### Product VS Age_Category
# - ### Product VS Gender
# - ### Product VS Education
# - ### Product VS MaritalStatus
# - ### Product VS Usage
# - ### Product VS Fitness
# - ### Product VS Fitness
# - ### Product VS Miles
# - ### Outlier detection Product vs Age
# - ### # Outlier detection Product vs Education
# - ### Outlier detection Product vs Usage
# - ### Outlier detection Product vs Fitness
# - ### Outlier detection Product vs Income
# - ### Outlier detection Product vs Miles
# - # Multivariate Analysis
# - ### Multivariate analysis of income age and Product
# - ### Outlier detection of gender vs Education with respect to product
# - ### Outlier detection of gender vs Income with respect to product
# - ### Probability of Product with respect to Gender
# - ### Probability of Product with respect to MaritalStatus
# - ### Probability of Product with respect to Age_Groups
# - ### Probability of Product with respect to Age_Category
# - ### Probability of Product with respect to Income_Groups
# - ### Probability of Product with respect to Education
# - ### Probability of Product with respect to Usage
# - ### Probability of Product with respect to Fitness
# - ### Probability of Product with respect to Income
# - ### Probability of Product with respect to Miles
# - ### Pie chart of product with respect to fitness
# - ### Pie chart of product with respect to Miles
# - ### Pie chart of product with respect to Income
# - ### Pie chart of product with respect to Age
# - ### Pie chart of product with respect to Usage
# - ### Fitness vs Income
# - ### Education vs Income
# - ### Unit product price vs Usage
# - ### Correlation of the data

# %%
#importing libraries for our purpose
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('aerofit_treadmill.csv')
df
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     KP281   18    Male         14        Single      3        4   29562
# 1     KP281   19    Male         15        Single      2        3   31836
# 2     KP281   19  Female         14     Partnered      4        3   30699
# 3     KP281   19    Male         12        Single      3        3   32973
# 4     KP281   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   KP781   40    Male         21        Single      6        5   83416
# 176   KP781   42    Male         18        Single      5        4   89641
# 177   KP781   45    Male         16        Single      5        5   90886
# 178   KP781   47    Male         18     Partnered      4        5  104581
# 179   KP781   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %%
#No of Rows and columns in data
print(f"Number of rows: {df.shape[0]}\nNumber of columns: {df.shape[1]}")
# Out:
# Number of rows: 180
# Number of columns: 9

# %%
#checking datatypes
df.dtypes
# Out:
# Product          object
# Age               int64
# Gender           object
# Education         int64
# MaritalStatus    object
# Usage             int64
# Fitness           int64
# Income            int64
# Miles             int64
# dtype: object

# %%
#checking information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
#Description of data
df.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %%
#Description of data
df.describe(include="all").T
# Out:
#                count unique        top freq          mean           std  \
# Product          180      3      KP281   80           NaN           NaN
# Age            180.0    NaN        NaN  NaN     28.788889      6.943498
# Gender           180      2       Male  104           NaN           NaN
# Education      180.0    NaN        NaN  NaN     15.572222      1.617055
# MaritalStatus    180      2  Partnered  107           NaN           NaN
# Usage          180.0    NaN        NaN  NaN      3.455556      1.084797
# Fitness        180.0    NaN        NaN  NaN      3.311111      0.958869
# Income         180.0    NaN        NaN  NaN  53719.577778  16506.684226
# Miles          180.0    NaN        NaN  NaN    103.194444     51.863605
#
#                    min       25%      50%      75%       max
# Product            NaN       NaN      NaN      NaN       NaN
# Age               18.0      24.0     26.0     33.0      50.0
# Gender             NaN       NaN      NaN      NaN       NaN
# ...

# %%
#Description of categorical values in data
df.describe(include='O').T
# Out:
#               count unique        top freq
# Product         180      3      KP281   80
# Gender          180      2       Male  104
# MaritalStatus   180      2  Partnered  107

# %%
#number of unique values in our data
for i in df.columns:
  print(i,':',df[i].nunique())
# Out:
# Product : 3
# Age : 32
# Gender : 2
# Education : 8
# MaritalStatus : 2
# Usage : 6
# Fitness : 5
# Income : 62
# Miles : 37

# %%
#columns in data
df.columns
# Out:
# Index(['Product', 'Age', 'Gender', 'Education', 'MaritalStatus', 'Usage',
#        'Fitness', 'Income', 'Miles'],
#       dtype='object')

# %%
#Shape of data
df.shape
# Out:
# (180, 9)

# %%
# Checking for duplicates
df.duplicated().value_counts()
# Out:
# False    180
# dtype: int64

# %%
#checking null values in every column of our data
df.isnull().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %%
#Gender value counts in data
df.Gender.value_counts()
# Out:
# Male      104
# Female     76
# Name: Gender, dtype: int64

# %%
df.Gender.value_counts(normalize=True)
# Out:
# Male      0.577778
# Female    0.422222
# Name: Gender, dtype: float64

# %%
#Product value counts in data
df.Product.value_counts()
# Out:
# KP281    80
# KP481    60
# KP781    40
# Name: Product, dtype: int64

# %%
df.Product.nunique()
# Out:
# 3

# %%
#Unique no of products in data
df.Product.unique()
# Out:
# array(['KP281', 'KP481', 'KP781'], dtype=object)

# %% [markdown]
# - ### There are 3 unique products available in the data

# %%
#MaritalStatus value counts in data
df.MaritalStatus.value_counts()
# Out:
# Partnered    107
# Single        73
# Name: MaritalStatus, dtype: int64

# %%
df.MaritalStatus.value_counts(normalize=True)
# Out:
# Partnered    0.594444
# Single       0.405556
# Name: MaritalStatus, dtype: float64

# %% [markdown]
# ## Observations:
#
# ### From the above observations, it is derived that,
# - ### There are no missing values in the data.
# - ### There are 3 unique products in the dataset.
# - ### **KP281** is the most frequent product.
# - ### Minimum age of the person is 18.
# - ### Maximum age of the person is 50.
# - ### 75% of persons have age less than or equal to 33.
# - ### mean age of the person is 28.79
# - ### mean usage is 3.46
# - ### Most of the people are having 16 years of education i.e. 75% of persons are having education <= 16 years.
# - ### Out of 180 data points, 104 gender is Male and 76 is female.
# - ### Standard deviation for **Income** & **Miles** is very high.

# %%
df[df['Product']=='KP281'].describe()
# Out:
#              Age  Education      Usage   Fitness       Income       Miles
# count  80.000000  80.000000  80.000000  80.00000     80.00000   80.000000
# mean   28.550000  15.037500   3.087500   2.96250  46418.02500   82.787500
# std     7.221452   1.216383   0.782624   0.66454   9075.78319   28.874102
# min    18.000000  12.000000   2.000000   1.00000  29562.00000   38.000000
# 25%    23.000000  14.000000   3.000000   3.00000  38658.00000   66.000000
# 50%    26.000000  16.000000   3.000000   3.00000  46617.00000   85.000000
# 75%    33.000000  16.000000   4.000000   3.00000  53439.00000   94.000000
# max    50.000000  18.000000   5.000000   5.00000  68220.00000  188.000000

# %%
df[df['Product']=='KP481'].describe()
# Out:
#              Age  Education      Usage   Fitness        Income       Miles
# count  60.000000  60.000000  60.000000  60.00000     60.000000   60.000000
# mean   28.900000  15.116667   3.066667   2.90000  48973.650000   87.933333
# std     6.645248   1.222552   0.799717   0.62977   8653.989388   33.263135
# min    19.000000  12.000000   2.000000   1.00000  31836.000000   21.000000
# 25%    24.000000  14.000000   3.000000   3.00000  44911.500000   64.000000
# 50%    26.000000  16.000000   3.000000   3.00000  49459.500000   85.000000
# 75%    33.250000  16.000000   3.250000   3.00000  53439.000000  106.000000
# max    48.000000  18.000000   5.000000   4.00000  67083.000000  212.000000

# %%
df[df['Product']=='KP781'].describe()
# Out:
#              Age  Education      Usage    Fitness        Income       Miles
# count  40.000000  40.000000  40.000000  40.000000      40.00000   40.000000
# mean   29.100000  17.325000   4.775000   4.625000   75441.57500  166.900000
# std     6.971738   1.639066   0.946993   0.667467   18505.83672   60.066544
# min    22.000000  14.000000   3.000000   3.000000   48556.00000   80.000000
# 25%    24.750000  16.000000   4.000000   4.000000   58204.75000  120.000000
# 50%    27.000000  18.000000   5.000000   5.000000   76568.50000  160.000000
# 75%    30.250000  18.000000   5.000000   5.000000   90886.00000  200.000000
# max    48.000000  21.000000   7.000000   5.000000  104581.00000  360.000000

# %% [markdown]
# ## From the above three tables,
#
# - ### KP781 customers had highest average income and education
# - ### which may be correlated with highest fitness, usage and miles.
# - ### This may be due to the KP781 being a more advanced model, which draws in the interest of customers that are more serious about their cardio. Along with this would be a higher price point.
# - ### KP281 and KP481 had similar metrics.

# %%
df_n=df[["Age","Education","Usage","Fitness","Miles"]]
df_n
# Out:
#      Age  Education  Usage  Fitness  Miles
# 0     18         14      3        4    112
# 1     19         15      2        3     75
# 2     19         14      4        3     66
# 3     19         12      3        3     85
# 4     20         13      4        2     47
# ..   ...        ...    ...      ...    ...
# 175   40         21      6        5    200
# 176   42         18      5        4    200
# 177   45         16      5        5    160
# 178   47         18      4        5    120
# 179   48         18      4        5    180
#
# [180 rows x 5 columns]

# %%
for i in df_n.columns:
  print(i,':',df_n[i].mean())
# Out:
# Age : 28.788888888888888
# Education : 15.572222222222223
# Usage : 3.4555555555555557
# Fitness : 3.311111111111111
# Miles : 103.19444444444444

# %%
for i in df_n.columns:
  print(i,':',df_n[i].median())
# Out:
# Age : 26.0
# Education : 16.0
# Usage : 3.0
# Fitness : 3.0
# Miles : 94.0

# %% [markdown]
# - ### Mean and Median value of miles have more variation

# %% [markdown]
# ## For the effective analyse arranging columns more convinient way

# %%
df1=df.copy()
bins2=[20000,40000,60000,80000,110000]
labels2=["20k-40k","40k-60k","6ok-80k","80k-1.1L"]
df1["Income"]=pd.cut(df1["Income"],bins=bins2,labels=labels2)
bins3=[0,50,100,150,200,250,300,350,400]
labels3=["0-50","50-100","100-150","150-200","200-250","250-300","300-350","350-400"]
df1["Miles"]=pd.cut(df1["Miles"],bins=bins3,labels=labels3)
df1
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness    Income  \
# 0     KP281   18    Male         14        Single      3        4   20k-40k
# 1     KP281   19    Male         15        Single      2        3   20k-40k
# 2     KP281   19  Female         14     Partnered      4        3   20k-40k
# 3     KP281   19    Male         12        Single      3        3   20k-40k
# 4     KP281   20    Male         13     Partnered      4        2   20k-40k
# ..      ...  ...     ...        ...           ...    ...      ...       ...
# 175   KP781   40    Male         21        Single      6        5  80k-1.1L
# 176   KP781   42    Male         18        Single      5        4  80k-1.1L
# 177   KP781   45    Male         16        Single      5        5  80k-1.1L
# 178   KP781   47    Male         18     Partnered      4        5  80k-1.1L
# 179   KP781   48    Male         18     Partnered      4        5  80k-1.1L
#
#        Miles
# 0    100-150
# 1     50-100
# ...

# %%
bins=[0,14,24,40,64,100]  
bins_income = [29000, 40000, 60000, 80000,105000]
label1=['0-14','15-24','25-40','41-64','65-100']
label2=['Children',"Youth", "Young Adults","Old Adults","Seniors"]
label3 = ['Low Income','Moderate Income','High Income','Very High Income']
df1['Age_Groups']=pd.cut(df['Age'],bins,labels = label1)
df1['Age_Category']=pd.cut(df['Age'],bins,labels = label2)
df1['Income_Groups'] = pd.cut(df['Income'],bins_income,labels = label3)
df1
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness    Income  \
# 0     KP281   18    Male         14        Single      3        4   20k-40k
# 1     KP281   19    Male         15        Single      2        3   20k-40k
# 2     KP281   19  Female         14     Partnered      4        3   20k-40k
# 3     KP281   19    Male         12        Single      3        3   20k-40k
# 4     KP281   20    Male         13     Partnered      4        2   20k-40k
# ..      ...  ...     ...        ...           ...    ...      ...       ...
# 175   KP781   40    Male         21        Single      6        5  80k-1.1L
# 176   KP781   42    Male         18        Single      5        4  80k-1.1L
# 177   KP781   45    Male         16        Single      5        5  80k-1.1L
# 178   KP781   47    Male         18     Partnered      4        5  80k-1.1L
# 179   KP781   48    Male         18     Partnered      4        5  80k-1.1L
#
#        Miles Age_Groups  Age_Category     Income_Groups
# ...

# %%
df1['Age_Category'].value_counts()
# Out:
# Young Adults    114
# Youth            54
# Old Adults       12
# Children          0
# Seniors           0
# Name: Age_Category, dtype: int64

# %% [markdown]
# # Including Product_price to the dataset

# %%
Product_Price = {'KP281' : '1500',
                'KP481' : '1750',
                'KP781' : '2500'}

# %%
df1['Unit Product Price'] = df1['Product'].replace(to_replace = Product_Price )
df1['Unit Product Price'].value_counts()
# Out:
# 1500    80
# 1750    60
# 2500    40
# Name: Unit Product Price, dtype: int64

# %%
price = df1['Unit Product Price'].unique()
price
# Out:
# array(['1500', '1750', '2500'], dtype=object)

# %%
quantity = df1['Unit Product Price'].value_counts()
quantity
# Out:
# 1500    80
# 1750    60
# 2500    40
# Name: Unit Product Price, dtype: int64

# %%
for i in range(len(price)):
    tot_sale_USD = quantity[i] * int(price[i])
    print("Total sales for treadmill of unit price ${} is ${}".format(int(price[i]),tot_sale_USD))
# Out:
# Total sales for treadmill of unit price $1500 is $120000
# Total sales for treadmill of unit price $1750 is $105000
# Total sales for treadmill of unit price $2500 is $100000

# %%
df1["Income"].min(),df1["Income"].max()
# Out:
# ('20k-40k', '80k-1.1L')

# %%
# Changing datatype of Unit Product Price from Object to int64.
df1['Unit Product Price'] = df1['Unit Product Price'].astype("int64")
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Product             180 non-null    object
#  1   Age                 180 non-null    int64
#  2   Gender              180 non-null    object
#  3   Education           180 non-null    int64
#  4   MaritalStatus       180 non-null    object
#  5   Usage               180 non-null    int64
#  6   Fitness             180 non-null    int64
#  7   Income              180 non-null    category
#  8   Miles               180 non-null    category
#  9   Age_Groups          180 non-null    category
#  10  Age_Category        180 non-null    category
#  11  Income_Groups       180 non-null    category
#  12  Unit Product Price  180 non-null    int64
# dtypes: category(5), int64(5), object(3)
# memory usage: 13.4+ KB

# %%
df1
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness    Income  \
# 0     KP281   18    Male         14        Single      3        4   20k-40k
# 1     KP281   19    Male         15        Single      2        3   20k-40k
# 2     KP281   19  Female         14     Partnered      4        3   20k-40k
# 3     KP281   19    Male         12        Single      3        3   20k-40k
# 4     KP281   20    Male         13     Partnered      4        2   20k-40k
# ..      ...  ...     ...        ...           ...    ...      ...       ...
# 175   KP781   40    Male         21        Single      6        5  80k-1.1L
# 176   KP781   42    Male         18        Single      5        4  80k-1.1L
# 177   KP781   45    Male         16        Single      5        5  80k-1.1L
# 178   KP781   47    Male         18     Partnered      4        5  80k-1.1L
# 179   KP781   48    Male         18     Partnered      4        5  80k-1.1L
#
# ...

# %% [markdown]
# # KDE Plot of Age vs Fitness

# %%
plt.figure(figsize=(10,5))
sns.kdeplot(data=df,x='Age',y='Fitness', shade=True,color="red")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fitness'>

# %% [markdown]
# - ### From the above plot, it is derived that the relation between Age and fitness.
# - ### here most of the fitness data is in between the age group of 20-30 and their corresponding average fitness rate is 3.

# %% [markdown]
# ## Pie chart of Product Sales

# %%
plt.figure(figsize=(8, 6))
df['Product'].value_counts().plot.pie(autopct='%1.1f%%',explode=(.1,0,0))
plt.title("Pie chart of Product Sales")
plt.show()

# %% [markdown]
# - ### From the above plot, it is derived that the distribution of Unit Product Price.
# - ### Product KP281 is the most selling model

# %% [markdown]
# ## Pie chart of Gender

# %%
plt.figure(figsize=(8, 6))
df['Gender'].value_counts().plot.pie(autopct='%1.1f%%')
plt.title("Pie chart of Product Sales")
plt.show()

# %% [markdown]
# - ### From the above plot, it is derived that the distribution of Gender category.
# - ### There are more male buyers then female buyers.

# %% [markdown]
# ## Pie chart of MaritalStatus

# %%
plt.figure(figsize=(8, 6))
df['MaritalStatus'].value_counts().plot.pie(autopct='%1.1f%%')
plt.title("Pie chart of Product Sales")
plt.show()

# %% [markdown]
# - ### From the above plot, it is derived that the distribution of Gender category.
# - ### Couples are buying more treadmills then singles.

# %%
print(f"Mean: {df['Age'].mean()}\nMedian: {df['Age'].median()}\nMode: {df['Age'].mode()[0]}")
# Out:
# Mean: 28.788888888888888
# Median: 26.0
# Mode: 25

# %%
print(f"Variance: {df['Age'].var()}\nStd: {df['Age'].std()}")
# Out:
# Variance: 48.21216635630043
# Std: 6.943498135399795

# %%
df.groupby(['Product', 'Gender']).agg(['mean', 'count', 'std'])
# Out:
# C:\Users\SIYAVUDEEN\AppData\Local\Temp\ipykernel_24196\3690588024.py:1: FutureWarning: ['MaritalStatus'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df.groupby(['Product', 'Gender']).agg(['mean', 'count', 'std'])
#                       Age                  Education                  \
#                      mean count       std       mean count       std
# Product Gender
# KP281   Female  28.450000    40  7.110664  15.100000    40  1.081310
#         Male    28.650000    40  7.419828  14.975000    40  1.349026
# KP481   Female  29.103448    29  5.802369  15.206897    29  1.292266
#         Male    28.709677    31  7.439505  15.032258    31  1.168585
# KP781   Female  27.000000     7  3.559026  17.857143     7  1.676163
#         Male    29.545455    33  7.462786  17.212121    33  1.634732
#
#                    Usage                   Fitness                  \
# ...

# %% [markdown]
# - ### From the above describes, The mean, count and standard deviation of the respective product with respect to gender.
# - ### There are more no of males as compared to female.
# - ### The mean age male and female for each products are almost equal.
# - ### In KP781 standard deviation for male and female is far.
# - ### The mean Education of KP781 is high, and in KP481 and KP281 are almost equal.
# - ### The mean usage of KP781 is higher than the others.
# - ### The mean fitness of KP781 is higher than the others.
# - ### The mean income of KP781 is higher than the others.
# - ### The mean miles of KP781 is higher than the others.
# - ### From the above declerations we can conclude Kp781 users having high education, usage, fitness, income and miles.

# %% [markdown]
# # Understanding the distribution of the data for the quantitative attributes:
#
# 1. Age
# 2. Education
# 3. Usage
# 4. Fitness
# 5. Income
# 6. Miles

# %%
fig, axis = plt.subplots(nrows=3, ncols=2, figsize=(12, 10))
fig.subplots_adjust(top=1.5)
sns.histplot(data=df, x="Age", kde=True,color="blue", ax=axis[0,0])
sns.histplot(data=df, x="Education", kde=True,color="green", ax=axis[0,1])
sns.histplot(data=df, x="Usage", kde=True,color="red", ax=axis[1,0])
sns.histplot(data=df, x="Fitness", kde=True,color="brown", ax=axis[1,1])
sns.histplot(data=df, x="Income", kde=True,color="indigo", ax=axis[2,0])
sns.histplot(data=df, x="Miles", kde=True,color="darkolivegreen", ax=axis[2,1])
plt.show()

# %% [markdown]
# - ### From the above plot, it is derived that the distribution of Age, Education, Usage, Fitness, Income, Miles.
#
# **1.Age**
# - Age is skewed towards right.
# - Most of the persons have age in between 20 to 35.
# - Customers buying treadmill after age of 40 and before 20 are very less.
#
# **2.Education**
# - Most customers have 16 years of Education.
#
# **3.Usage**
# - Majority of users prefers to use Treadmills 3-4 times/week.
#
# **4.Fitness**
# - Most customers have 3-3.5 fitness rating (moderate fit).
# - Very few customers that uses treadmill have low score i.e 1.
#
# **5.Income**
# - Income is skewed toward right.
# - Most customers have income less than 70k.
#
# **6.Miles**
# - Miles is skewed towards right.
# - Highest no of peoples walks between 50 to 150 miles.
# - Customers run on an average 80 miles per week.

# %% [markdown]
# # Outliers detection using BoxPlots

# %% [markdown]
# ## Outliers detection for Age

# %%
plt.figure(figsize=(13,7))
sns.boxplot(data=df, x="Age")
plt.show()

# %% [markdown]
# - ### From the above plot, it is derived that the outlier detection of Age.
# - ### Age has only very few outlier values.
# - ### Most of the customers are in the 24-34 range with a right-skewed distribution for Age.

# %% [markdown]
# ## Outliers detection for Education

# %%
plt.figure(figsize=(13,7))
sns.boxplot(data=df, x="Education")
plt.show()

# %% [markdown]
# - ### From the above plot, it is derived that the outlier detection of Education.
# - ### Education has only very few outlier values.
# - ### Most of the customers are in the 14-16 range with a right-skewed distribution for Education.

# %% [markdown]
# ## Outliers detection for Usage

# %%
plt.figure(figsize=(13,7))
sns.boxplot(data=df, x="Usage")
plt.show()

# %% [markdown]
# - ### From the above plot, it is derived that the outlier detection of Usage.
# - ### Usage has only very few outlier values
# - ### Most of the customers are in the 3-4 range with a right-skewed distribution for Usage.

# %% [markdown]
# ## Outliers detection for Fitness

# %%
plt.figure(figsize=(13,7))
sns.boxplot(data=df, x="Fitness")
plt.show()

# %% [markdown]
# - ### From the above plot, it is derived that the outlier detection of Fitness.
# - ### Fitness has only very few outlier values.
# - ### Most of the customers are in the 3.0-4.0 range with a right-skewed distribution for Fitness.

# %% [markdown]
# ## Outliers detection for Income

# %%
plt.figure(figsize=(13,7))
sns.boxplot(data=df, x="Income")
plt.show()

# %% [markdown]
# - ### From the above plot, it is derived that the outlier detection of Income.
# - ### Income has More no of outlier values.
# - ### There are customers that earn more than approx. 77K, which are featured outliers.
# - ### These are likely the customers purchasing the KP781 model.
# - ### Most of the customers are in the 40K-60K range with a right-skewed distribution for income.

# %% [markdown]
# ## Outliers detection for Miles

# %%
plt.figure(figsize=(13,7))
sns.boxplot(data=df, x="Miles")
plt.show()

# %% [markdown]
# - ### From the above plot, it is derived that the outlier detection of Miles.
# - ### Miles has More no of outlier values.
# - ### Right-skewed distribution, with average at about 80 miles.
# - ### Most of the customers are in the 50-120 range with a right-skewed distribution for Miles.

# %% [markdown]
#  ## From the above outlier detections,
# - ### Age, Education, Usage and Fitness are having very few outliers.
# - ### While Income and Miles are having more outliers.

# %% [markdown]
# # Outlier handling for income

# %%
q1=df['Income'].quantile(.25)
q2=df['Income'].median()
q3=df['Income'].quantile(.75)
iqr=q3-q1 
df_in=df[(df['Income']>q1-1.5*iqr)&(df['Income']<q3+1.5*iqr)]
df_in.shape
# Out:
# (161, 9)

# %% [markdown]
# - ### After outlier removal for income, 19 rows are deleted

# %% [markdown]
# ## Boxplot for income before removing outlier

# %%
plt.figure(figsize=(13,7))
sns.boxplot(data = df, x = 'Miles')
plt.show()

# %% [markdown]
# - ### From the above plot, it is derived that the outlier detection of Income.
# - ### we can see more no outliers through the boxplot

# %% [markdown]
# ## Boxplot for income after removing outlier

# %%
plt.figure(figsize=(13,7))
sns.boxplot(data = df_in, x = 'Miles')
plt.show()

# %% [markdown]
# - ### From the above plot, it is derived that the outlier detection of Income.
# - ### In the boxplot, we can clearly see that most of the outliers are removed

# %% [markdown]
# ## Boxplot for Gender and the Income of customers purchasing products before outlier removal

# %%
plt.figure(figsize=(13,7))
sns.boxplot(data=df, x = 'Gender', y = 'Income')
plt.show()

# %% [markdown]
# - ### From the above plot, it is derived that the outlier detection of Income and gender.
# - ### we can see more no outliers through the boxplot

# %% [markdown]
# ## Boxplot for Gender and the Income of customers purchasing products after outlier removal

# %%
plt.figure(figsize=(13,7))
sns.boxplot(data=df_in, x = 'Gender', y = 'Income')
plt.show()

# %% [markdown]
# - ### From the above plot, it is derived that the outlier detection of Income and gender.
# - ### In the boxplot, we can clearly see that most of the outliers are removed

# %% [markdown]
# ## Mean before removing outlier values

# %%
df.groupby('Gender')['Income'].mean()
# Out:
# Gender
# Female    49828.907895
# Male      56562.759615
# Name: Income, dtype: float64

# %% [markdown]
# ## Mean after outlier removal

# %%
df_in.groupby('Gender')['Income'].mean()
# Out:
# Gender
# Female    48056.356164
# Male      50000.840909
# Name: Income, dtype: float64

# %% [markdown]
# - ### From the above we can see the difference of mean value before and after outlier removal

# %% [markdown]
# # Outlier handling for Miles

# %%
q1=df['Miles'].quantile(.25)
q2=df['Miles'].median()
q3=df['Miles'].quantile(.75)
iqr=q3-q1 
df_mi=df[(df['Miles']>q1-1.5*iqr)&(df['Miles']<q3+1.5*iqr)]
df_mi.shape
# Out:
# (167, 9)

# %% [markdown]
# - ### After outlier removal for Miles, 13 rows are deleted

# %% [markdown]
# ## Boxplot for Miles before removing outlier

# %%
plt.figure(figsize=(13,7))
sns.boxplot(data = df, x = 'Miles')
plt.show()

# %% [markdown]
# - ### From the above plot, it is derived that the outlier detection of miles.
# - ### we can see more no outliers through the boxplot.

# %% [markdown]
# ## Boxplot for Miles after removing outlier

# %%
plt.figure(figsize=(13,7))
sns.boxplot(data = df_mi, x = 'Miles')
plt.show()

# %% [markdown]
# - ### From the above plot, it is derived that the outlier detection of miles.
# - ### In the boxplot, we can clearly see that most of the outliers are removed.

# %% [markdown]
# ## Boxplot for Gender and the Miles of customers purchasing products before outlier removal

# %%
plt.figure(figsize=(13,7))
sns.boxplot(data=df, x = 'Gender', y = 'Miles')
plt.show()

# %% [markdown]
# - ### From the above plot, it is derived that the outlier detection of miles and gender.
# - ### we can see more no outliers through the boxplot

# %% [markdown]
# ## Boxplot for Gender and the Miles of customers purchasing products after outlier removal

# %%
plt.figure(figsize=(13,7))
sns.boxplot(data=df_mi, x = 'Gender', y = 'Miles')
plt.show()

# %% [markdown]
# - ### From the above plot, it is derived that the outlier detection of miles and gender.
# - ### In the boxplot, we can clearly see that most of the outliers are removed

# %% [markdown]
# ## Mean before outlier removal

# %%
df.groupby('Gender')['Miles'].mean()
# Out:
# Gender
# Female     90.013158
# Male      112.826923
# Name: Miles, dtype: float64

# %% [markdown]
# ## Mean after outlier removal

# %%
df_mi.groupby('Gender')['Miles'].mean()
# Out:
# Gender
# Female     79.442857
# Male      102.824742
# Name: Miles, dtype: float64

# %% [markdown]
# - ### From the above we can see the difference of mean value before and after outlier removal

# %% [markdown]
# # EDA - Bivariate Analysis

# %%
sns.lineplot(data=df, x='Age', y='Income', hue="Product")
plt.show()

# %%
sns.lineplot(data=df_in, x='Age', y='Income', hue="Product")
plt.show()

# %% [markdown]
# - ### Here we can clearly see that, most of the buyers who have income greater than 80K, prefers to buy product KP781 with advanced features.
# - ### Also, as the second graph without income ouliers, we aren't getting any significant disturbances expect the higher income group, hence it's benefetial to keep outliers i.e first (df) for further inferences.

# %%
new_mean= round(df_in.mean(),2)
new_mean
# Out:
# C:\Users\SIYAVUDEEN\AppData\Local\Temp\ipykernel_24196\642635700.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   new_mean= round(df_in.mean(),2)
# Age             28.16
# Education       15.35
# Usage            3.27
# Fitness          3.14
# Income       49119.18
# Miles           93.26
# dtype: float64

# %%
new_median = df_in.median()
new_median
# Out:
# C:\Users\SIYAVUDEEN\AppData\Local\Temp\ipykernel_24196\2375243832.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   new_median = df_in.median()
# Age             26.0
# Education       16.0
# Usage            3.0
# Fitness          3.0
# Income       48891.0
# Miles           85.0
# dtype: float64

# %%
# Difference in the mean and median of Income before removing outliers
diff_org = round(df['Income'].mean()-df['Income'].median(),2)
diff_org
# Out:
# 3123.08

# %%
# Difference in the mean and median of Income after removing outliers
diff_new = round(df_in['Income'].mean()-df_in['Income'].median(),2)
diff_new
# Out:
# 228.18

# %%
diff_in_income = round((diff_new/diff_org) *100,2)
diff_in_income
# Out:
# 7.31

# %% [markdown]
# ### From above,
# - ### we can infer that, there's a 7.31% correction in the Income data after removing outliers as we can see that the difference in the mean and median has decreased from 3123 to 228.
# - ### Hence the new dataframe i.e (df_in) is more suitable for carrying further analysis with respect to income and gender related cases.

# %% [markdown]
# ## Product counts

# %%
plt.figure(figsize=(13,8))
sns.countplot(data=df, x='Product')
plt.title("Product - counts", pad=10, fontsize=14)
# Out:
# Text(0.5, 1.0, 'Product - counts')

# %% [markdown]
# - ### From the above plot, it is derived that the Product counts of treadmills.
# - ###  Most of the the treadmills sold are KP281 and the least sold are KP781.

# %% [markdown]
# ## Gender Counts

# %%
plt.figure(figsize=(13,8))
sns.countplot(data=df, x='Gender')
plt.title("Gender - counts", pad=10, fontsize=14)
# Out:
# Text(0.5, 1.0, 'Gender - counts')

# %% [markdown]
# - ### From the above plot, it is derived that the Gender counts of treadmills.
# - ### Thare are more Males in the data than Females.

# %% [markdown]
# ## MaritalStatus Counts

# %%
plt.figure(figsize=(13,8))
sns.countplot(data=df, x='MaritalStatus')
plt.title("MaritalStatus - counts", pad=10, fontsize=14)
# Out:
# Text(0.5, 1.0, 'MaritalStatus - counts')

# %% [markdown]
# - ### From the above plot, it is derived that the Gender counts of treadmills.
# - ###  There are less single consumers than partnered consumers.

# %% [markdown]
# # Variable counts

# %%
df2 = df[['Product', 'Gender', 'MaritalStatus']].melt()
df2.groupby(['variable', 'value'])[['value']].count()
# Out:
#                          value
# variable      value
# Gender        Female        76
#               Male         104
# MaritalStatus Partnered    107
#               Single        73
# Product       KP281         80
#               KP481         60
#               KP781         40

# %%
df2 = df[['Product', 'Gender', 'MaritalStatus']].melt()
df2.groupby(['variable', 'value'])[['value']].count()/len(df)
# Out:
#                             value
# variable      value
# Gender        Female     0.422222
#               Male       0.577778
# MaritalStatus Partnered  0.594444
#               Single     0.405556
# Product       KP281      0.444444
#               KP481      0.333333
#               KP781      0.222222

# %% [markdown]
# ### From the above,
# - ### more no of males than females.
# - ### In martialstatus more no of partnered (couples) than singles.
# - ### In products KP281 is the most no of peoples used

# %% [markdown]
# # Bivariate Analysis

# %%
df1
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness    Income  \
# 0     KP281   18    Male         14        Single      3        4   20k-40k
# 1     KP281   19    Male         15        Single      2        3   20k-40k
# 2     KP281   19  Female         14     Partnered      4        3   20k-40k
# 3     KP281   19    Male         12        Single      3        3   20k-40k
# 4     KP281   20    Male         13     Partnered      4        2   20k-40k
# ..      ...  ...     ...        ...           ...    ...      ...       ...
# 175   KP781   40    Male         21        Single      6        5  80k-1.1L
# 176   KP781   42    Male         18        Single      5        4  80k-1.1L
# 177   KP781   45    Male         16        Single      5        5  80k-1.1L
# 178   KP781   47    Male         18     Partnered      4        5  80k-1.1L
# 179   KP781   48    Male         18     Partnered      4        5  80k-1.1L
#
# ...

# %% [markdown]
# ## Product VS Age_Category

# %%
plt.figure(figsize=(13,7))
sns.countplot(data=df1, x='Product', hue='Age_Category', edgecolor="0.15", palette='Set2')
plt.show()

# %% [markdown]
# - ### From the above plot, it is derived that the product and age_category counts of treadmills.
# - ### Most of the product users are Young adults.
# - ### old adults are the least number.

# %% [markdown]
# ## Product VS Gender

# %%
plt.figure(figsize=(13,7))
sns.countplot(data=df, x='Product', hue='Gender', edgecolor="0.15", palette='Set2')
plt.show()

# %% [markdown]
# - ### From the above plot, it is derived that the product and Gender counts of treadmills.
# - ### More male customers purchased KP781.
# - ### KP281 had an equal amount of male and female buyers.

# %% [markdown]
# ## Product VS Education

# %%
plt.figure(figsize=(13,7))
sns.countplot(data=df, x='Product', hue='Education', edgecolor="0.15", palette='Set2')
plt.show()

# %% [markdown]
# - ### From the above plot, it is derived that the product and Education counts of treadmills.
# - ### Most of the product users are 16.
# - ### In Persons using KP281.
# - ### In KP781 most of the users are age 16+.

# %% [markdown]
# ## Product VS MaritalStatus

# %%
plt.figure(figsize=(13,7))
sns.countplot(data=df, x='Product', hue='MaritalStatus', edgecolor="0.15", palette='Set1')
plt.show()

# %% [markdown]
# - ### From the above plot, it is derived that the product and MaritalStatus counts of treadmills.
# - ### here were more partnered customers than single.
# - ### KP281 was more popular, although this may be due to the amount of KP281 sold being the highest.

# %% [markdown]
# ## Product VS Usage

# %%
plt.figure(figsize=(13,7))
sns.countplot(data=df, x='Product', hue='Usage', edgecolor="0.15", palette='Set2')
plt.show()

# %% [markdown]
# - ### From the above plot, it is derived that the product and Usage counts of treadmills.
# - ### In KP281 and KP481 Most of the usagers are using 3days in a week.
# - ### Most of the high level usagers are using KP781

# %% [markdown]
# ## Product VS Fitness

# %%
plt.figure(figsize=(13,7))
sns.countplot(data=df, x='Product', hue='Fitness', edgecolor="0.15", palette='Set2')
plt.show()

# %% [markdown]
# - ### From the above plot, it is derived that the product and Fitness counts of treadmills.
# - ### In  KP281 and KP481 most of the users are level 3.
# - ### Most of the high level  fitness peoples are in KP781.

# %% [markdown]
# ## Product VS Income

# %%
plt.figure(figsize=(13,7))
sns.countplot(data=df1, x='Product', hue='Income', edgecolor="0.15", palette='Set2')
plt.show()

# %% [markdown]
# - ### From the above plot, it is derived that the product and Income counts of treadmills.
# - ### In KP281 and KP481 Most of the users income range between 40k to 60k.
# - ### Most of the high income peoples are using KP781.

# %% [markdown]
# ## Product VS Miles

# %%
plt.figure(figsize=(13,7))
sns.countplot(data=df1, x='Product', hue='Miles', edgecolor="0.15", palette='Set2')
plt.show()

# %% [markdown]
# - ### From the above plot, it is derived that the product and Miles counts of treadmills.
# - ### In KP281 and KP481 Most of the users MILES range between 50 to 100 Miles.
# - ### Most of the high level users are in KP781.

# %% [markdown]
# # Outlier detection Product vs Age

# %%
plt.figure(figsize=(13,8))
sns.boxplot(x="Product", y="Age", data=df)
plt.show()

# %% [markdown]
# - ### From the above plot, it is derived that the Outlier of Product vs Age.
# - ### KP781 has more no of outlier values.

# %% [markdown]
# # Outlier detection Product vs Education

# %%
plt.figure(figsize=(13,8))
sns.boxplot(x="Product", y="Education", data=df)
plt.show()

# %% [markdown]
# - ### From the above plot, it is derived that the Outlier of Product vs Education.
# - ### No outlier values in Product vs Education.

# %% [markdown]
# # Outlier detection Product vs Usage

# %%
plt.figure(figsize=(13,8))
sns.boxplot(x="Product", y="Usage", data=df)
plt.show()

# %%
plt.figure(figsize=(13,8))
sns.violinplot(x="Product", y="Usage", data=df)
plt.show()

# %% [markdown]
# - ### From the above plot, it is derived that the Outlier of Product vs Usage.
# - ### KP481 has more no of outlier values.

# %% [markdown]
# # Outlier detection Product vs Fitness

# %%
plt.figure(figsize=(13,8))
sns.boxplot(x="Product", y="Fitness", data=df)
plt.show()

# %%
plt.figure(figsize=(13,8))
sns.violinplot(x="Product", y="Fitness", data=df)
plt.show()

# %% [markdown]
# - ### From the above plot, it is derived that the Outlier of Product vs Fitness.
# - ### KP281 and KP481 has more no of outlier values.

# %% [markdown]
# # Outlier detection Product vs Income

# %%
plt.figure(figsize=(13,8))
sns.boxplot(x="Product", y="Income", data=df)
plt.show()

# %% [markdown]
# - ### From the above plot, it is derived that the Outlier of Product vs Income.

# %% [markdown]
# # Outlier detection Product vs Miles

# %%
plt.figure(figsize=(13,8))
sns.boxplot(x="Product", y="Miles", data=df)
plt.show()

# %% [markdown]
# - ### From the above plot, it is derived that the Outlier of Product vs mILES.
# - ### KP281 and KP481 has more no of outlier values.

# %% [markdown]
# # Multivariate Analysis

# %% [markdown]
# ## Multivariate analysis of income age and Product

# %%
plt.figure(figsize=(13,8))
sns.barplot(x='Income',  y='Age',hue='Product',  data=df1)
plt.show()

# %% [markdown]
# - ### From the above plot, it is derived that the counts ofincome age and products.
# - ### Income range of 60k-80k are the highest users of all products.

# %% [markdown]
# ## Outlier detection of gender vs Education with respect to product

# %%
plt.figure(figsize=(13,8))
sns.boxplot(x="Gender", y="Education",hue="Product", data=df)
plt.show()

# %% [markdown]
# - ### From the above plot, it is derived that the gender education and product.
# - ### In KP281 and KP481 the median level of data for both male and female was similar.

# %% [markdown]
# ## Outlier detection of gender vs Income with respect to product

# %%
plt.figure(figsize=(13,8))
sns.boxplot(x="Gender", y="Income",hue="Product", data=df)
plt.show()

# %% [markdown]
# - ### From the above plot, it is derived that the gender Income and product.
# - ### In KP781 both the male and female have high range of income.

# %% [markdown]
# # Probability of Product with respect to Gender

# %%
df3=pd.crosstab(index=df['Gender'], columns=[df['Product']],margins=True)
df3["P(KP281/Gender)"] = df3['KP281']/df3["All"]
df3["P(KP481/Gender)"] = df3['KP481']/df3["All"]
df3["P(KP781/Gender)"] = df3['KP781']/df3["All"]
df3
# Out:
# Product  KP281  KP481  KP781  All  P(KP281/Gender)  P(KP481/Gender)  \
# Gender
# Female      40     29      7   76         0.526316         0.381579
# Male        40     31     33  104         0.384615         0.298077
# All         80     60     40  180         0.444444         0.333333
#
# Product  P(KP781/Gender)
# Gender
# Female          0.092105
# Male            0.317308
# All             0.222222

# %% [markdown]
# - ### From the above table,  it is derived that the probability of the product with respect to gender.
# - ### here most of the females are using KP281.
# - ### In male users highly using product was KP281, and probability of using each product was almost similar.

# %% [markdown]
# # Probability of Product with respect to MaritalStatus

# %%
df4 = pd.crosstab(index=df['MaritalStatus'], columns=[df['Product']],margins=True)
df4["P(KP281/MaritalStatus)"] = df4['KP281']/df4["All"]
df4["P(KP481/MaritalStatus)"] = df4['KP481']/df4["All"]
df4["P(KP781/MaritalStatus)"] = df4['KP781']/df4["All"]
df4
# Out:
# Product        KP281  KP481  KP781  All  P(KP281/MaritalStatus)  \
# MaritalStatus
# Partnered         48     36     23  107                0.448598
# Single            32     24     17   73                0.438356
# All               80     60     40  180                0.444444
#
# Product        P(KP481/MaritalStatus)  P(KP781/MaritalStatus)
# MaritalStatus
# Partnered                    0.336449                0.214953
# Single                       0.328767                0.232877
# All                          0.333333                0.222222

# %% [markdown]
# - ### From the above table,  it is derived that the probability of the product with respect to MaritalStatus.
# - ### here KP281 has the highest probability.
# - ### here probability for both the partnered and singles having only small amount of variations.

# %% [markdown]
# # Probability of Product with respect to Age_Groups

# %%
df4 = pd.crosstab(index=df1['Age_Groups'], columns=[df1['Product']],margins=True)
df4["P(KP281/Age_Groups)"] = df4['KP281']/df4["All"]
df4["P(KP481/Age_Groups)"] = df4['KP481']/df4["All"]
df4["P(KP781/Age_Groups)"] = df4['KP781']/df4["All"]
df4
# Out:
# Product     KP281  KP481  KP781  All  P(KP281/Age_Groups)  \
# Age_Groups
# 15-24          27     17     10   54             0.500000
# 25-40          47     41     26  114             0.412281
# 41-64           6      2      4   12             0.500000
# All            80     60     40  180             0.444444
#
# Product     P(KP481/Age_Groups)  P(KP781/Age_Groups)
# Age_Groups
# 15-24                  0.314815             0.185185
# 25-40                  0.359649             0.228070
# 41-64                  0.166667             0.333333
# All                    0.333333             0.222222

# %% [markdown]
# - ### From the above table,  it is derived that the probability of the product with respect to Age_Groups.
# - ### here in all age groups KP281 has the highest probability.
# - ### In age group of 15-24 and 41-64 KP281 has the highest probability(.5).

# %% [markdown]
# # Probability of Product with respect to Age_Category

# %%
df4 = pd.crosstab(index=df1['Age_Category'], columns=[df1['Product']],margins=True)
df4["P(KP281/Age_Category)"] = df4['KP281']/df4["All"]
df4["P(KP481/Age_Category)"] = df4['KP481']/df4["All"]
df4["P(KP781/Age_Category)"] = df4['KP781']/df4["All"]
df4
# Out:
# Product       KP281  KP481  KP781  All  P(KP281/Age_Category)  \
# Age_Category
# Youth            27     17     10   54               0.500000
# Young Adults     47     41     26  114               0.412281
# Old Adults        6      2      4   12               0.500000
# All              80     60     40  180               0.444444
#
# Product       P(KP481/Age_Category)  P(KP781/Age_Category)
# Age_Category
# Youth                      0.314815               0.185185
# Young Adults               0.359649               0.228070
# Old Adults                 0.166667               0.333333
# All                        0.333333               0.222222

# %% [markdown]
# - ### From the above table,  it is derived that the probability of the product with respect to Age_Category.
# - ### here in all age categories KP281 has the highest probability.
# - ### In age category of youth and old adults KP281 has the highest probability(.5).

# %% [markdown]
# # Probability of Product with respect to Income_Groups

# %%
df4 = pd.crosstab(index=df1['Income_Groups'], columns=[df1['Product']],margins=True)
df4["P(KP281/Income_Groups)"] = df4['KP281']/df4["All"]
df4["P(KP481/Income_Groups)"] = df4['KP481']/df4["All"]
df4["P(KP781/Income_Groups)"] = df4['KP781']/df4["All"]
df4
# Out:
# Product           KP281  KP481  KP781  All  P(KP281/Income_Groups)  \
# Income_Groups
# Low Income           23      9      0   32                0.718750
# Moderate Income      51     44     11  106                0.481132
# High Income           6      7     10   23                0.260870
# Very High Income      0      0     19   19                0.000000
# All                  80     60     40  180                0.444444
#
# Product           P(KP481/Income_Groups)  P(KP781/Income_Groups)
# Income_Groups
# Low Income                      0.281250                0.000000
# Moderate Income                 0.415094                0.103774
# High Income                     0.304348                0.434783
# Very High Income                0.000000                1.000000
# All                             0.333333                0.222222

# %% [markdown]
# - ### From the above table,  it is derived that the probability of the product with respect to Income_Groups.
# - ### In KP281 highest probability of users are Low income.
# - ### here No low income peples purchased KP781 and No high income peoples purchased KP281 and KP781.

# %% [markdown]
# # Probability of Product with respect to Education

# %%
df4 = pd.crosstab(index=df1['Education'], columns=[df1['Product']],margins=True)
df4["P(KP281/Education)"] = df4['KP281']/df4["All"]
df4["P(KP481/Education)"] = df4['KP481']/df4["All"]
df4["P(KP781/Education)"] = df4['KP781']/df4["All"]
df4
# Out:
# Product    KP281  KP481  KP781  All  P(KP281/Education)  P(KP481/Education)  \
# Education
# 12             2      1      0    3            0.666667            0.333333
# 13             3      2      0    5            0.600000            0.400000
# 14            30     23      2   55            0.545455            0.418182
# 15             4      1      0    5            0.800000            0.200000
# 16            39     31     15   85            0.458824            0.364706
# 18             2      2     19   23            0.086957            0.086957
# 20             0      0      1    1            0.000000            0.000000
# 21             0      0      3    3            0.000000            0.000000
# All           80     60     40  180            0.444444            0.333333
#
# Product    P(KP781/Education)
# Education
# 12                   0.000000
# 13                   0.000000
# 14                   0.036364
# 15                   0.000000
# ...

# %% [markdown]
# - ### From the above table,  it is derived that the probability of the product with respect to Education.
# - ### here Most of the high level of educated poeples use KP781.
# - ### Less educated peoples are mostly using KP281 and KP481.
# - ### In the education range of 20 and 21 the probability of using KP781 is 1.
# - ### In the education range of 12 and 13 the probability of using KP781 is 0.

# %% [markdown]
# # Probability of Product with respect to Usage

# %%
df4 = pd.crosstab(index=df1['Usage'], columns=[df1['Product']],margins=True)
df4["P(KP281/Usage)"] = df4['KP281']/df4["All"]
df4["P(KP481/Usage)"] = df4['KP481']/df4["All"]
df4["P(KP781/Usage)"] = df4['KP781']/df4["All"]
df4
# Out:
# Product  KP281  KP481  KP781  All  P(KP281/Usage)  P(KP481/Usage)  \
# Usage
# 2           19     14      0   33        0.575758        0.424242
# 3           37     31      1   69        0.536232        0.449275
# 4           22     12     18   52        0.423077        0.230769
# 5            2      3     12   17        0.117647        0.176471
# 6            0      0      7    7        0.000000        0.000000
# 7            0      0      2    2        0.000000        0.000000
# All         80     60     40  180        0.444444        0.333333
#
# Product  P(KP781/Usage)
# Usage
# 2              0.000000
# 3              0.014493
# 4              0.346154
# 5              0.705882
# 6              1.000000
# 7              1.000000
# All            0.222222

# %% [markdown]
# - ### From the above table,  it is derived that the probability of the product with respect to Usage.
# - ### here high level users are tendly to use KP781.
# - ### In level 2 and 3 users more tendly use KP281, with the probability range more than 0.5.
# - ### NO less users using KP781 treadmill.

# %% [markdown]
# # Probability of Product with respect to Fitness

# %%
df4 = pd.crosstab(index=df1['Fitness'], columns=[df1['Product']],margins=True)
df4["P(KP281/Fitness)"] = df4['KP281']/df4["All"]
df4["P(KP481/Fitness)"] = df4['KP481']/df4["All"]
df4["P(KP781/Fitness)"] = df4['KP781']/df4["All"]
df4
# Out:
# Product  KP281  KP481  KP781  All  P(KP281/Fitness)  P(KP481/Fitness)  \
# Fitness
# 1            1      1      0    2          0.500000          0.500000
# 2           14     12      0   26          0.538462          0.461538
# 3           54     39      4   97          0.556701          0.402062
# 4            9      8      7   24          0.375000          0.333333
# 5            2      0     29   31          0.064516          0.000000
# All         80     60     40  180          0.444444          0.333333
#
# Product  P(KP781/Fitness)
# Fitness
# 1                0.000000
# 2                0.000000
# 3                0.041237
# 4                0.291667
# 5                0.935484
# All              0.222222

# %% [markdown]
# - ### From the above table,  it is derived that the probability of the product with respect to Fitness.
# - ### Here most fitness maintaining peoples uses KP781.
# - ### No less fitness peoples using KP781.

# %% [markdown]
# # Probability of Product with respect to Income

# %%
df4 = pd.crosstab(index=df1['Income'], columns=[df1['Product']],margins=True)
df4["P(KP281/Income)"] = df4['KP281']/df4["All"]
df4["P(KP481/Income)"] = df4['KP481']/df4["All"]
df4["P(KP781/Income)"] = df4['KP781']/df4["All"]
df4
# Out:
# Product   KP281  KP481  KP781  All  P(KP281/Income)  P(KP481/Income)  \
# Income
# 20k-40k      23      9      0   32         0.718750         0.281250
# 40k-60k      51     44     11  106         0.481132         0.415094
# 6ok-80k       6      7     10   23         0.260870         0.304348
# 80k-1.1L      0      0     19   19         0.000000         0.000000
# All          80     60     40  180         0.444444         0.333333
#
# Product   P(KP781/Income)
# Income
# 20k-40k          0.000000
# 40k-60k          0.103774
# 6ok-80k          0.434783
# 80k-1.1L         1.000000
# All              0.222222

# %% [markdown]
# - ### From the above table,  it is derived that the probability of the product with respect to Income.
# - ### high income peoples more tendly to use KP781.
# - ### here the income range of 80k to 1.1L  peoples the probability of using KP781 IS 1.
# - ### Here less income peoples more tendly to use KP281.

# %% [markdown]
# # Probability of Product with respect to Miles

# %%
df4 = pd.crosstab(index=df1['Miles'], columns=[df1['Product']],margins=True)
df4["P(KP281/Miles)"] = df4['KP281']/df4["All"]
df4["P(KP481/Miles)"] = df4['KP481']/df4["All"]
df4["P(KP781/Miles)"] = df4['KP781']/df4["All"]
df4
# Out:
# Product  KP281  KP481  KP781  All  P(KP281/Miles)  P(KP481/Miles)  \
# Miles
# 0-50        12      5      0   17        0.705882        0.294118
# 50-100      50     39      8   97        0.515464        0.402062
# 100-150     16     13      9   38        0.421053        0.342105
# 150-200      2      2     18   22        0.090909        0.090909
# 200-250      0      1      1    2        0.000000        0.500000
# 250-300      0      0      3    3        0.000000        0.000000
# 350-400      0      0      1    1        0.000000        0.000000
# All         80     60     40  180        0.444444        0.333333
#
# Product  P(KP781/Miles)
# Miles
# 0-50           0.000000
# 50-100         0.082474
# 100-150        0.236842
# 150-200        0.818182
# 200-250        0.500000
# 250-300        1.000000
# 350-400        1.000000
# All            0.222222

# %% [markdown]
# - ### From the above table,  it is derived that the probability of the product with respect to Miles.
# - ### Here people using more than 150 miles more tendly to use the product KP781.
# - ### Less miles running peoples mostly using KP281.

# %% [markdown]
# # Pie chart of product with respect to fitness

# %%
plt.figure(figsize=(13,8))
A=df.groupby('Product')['Fitness'].mean().plot.pie(autopct='%.1f%%', explode=(0,0,.1))
A
# Out:
# <AxesSubplot:ylabel='Fitness'>

# %% [markdown]
# - ### From the above plot, it is derived that the mean of product with respect to fitness.
# - ### Here most of the fitness people (44.8%) using KP781 treadmill.

# %% [markdown]
# # Pie chart of product with respect to Miles

# %%
plt.figure(figsize=(13,8))
df.groupby('Product')['Miles'].mean().plot.pie(autopct='%.1f%%', explode=(0,0,.1))
# Out:
# <AxesSubplot:ylabel='Miles'>

# %% [markdown]
# - ### From the above plot, it is derived that the mean of product with respect to Miles.
# - ### Here most of the miles running people (49.4%) using KP781 treadmill.

# %% [markdown]
# # Pie chart of product with respect to Income

# %%
plt.figure(figsize=(13,8))
df.groupby('Product')['Income'].mean().plot.pie(autopct='%.1f%%', explode=(0,0,.1))
# Out:
# <AxesSubplot:ylabel='Income'>

# %% [markdown]
# - ### From the above plot, it is derived that the mean of product with respect to Income.
# - ### Here most of the Income earning people (44.2%) using KP781 treadmill.

# %% [markdown]
# # Pie chart of product with respect to Age

# %%
plt.figure(figsize=(13,8))
df.groupby('Product')['Age'].mean().plot.pie(autopct='%.1f%%', explode=(0,0,.1))
# Out:
# <AxesSubplot:ylabel='Age'>

# %% [markdown]
# - ### From the above plot, it is derived that the mean of product with respect to Age.
# - ### Here all the three product have around similar age mean.

# %% [markdown]
# # Pie chart of product with respect to Usage

# %%
plt.figure(figsize=(13,8))
df.groupby('Product')['Usage'].mean().plot.pie(autopct='%.1f%%', explode=(0,0,.1))
# Out:
# <AxesSubplot:ylabel='Usage'>

# %% [markdown]
# - ### From the above plot, it is derived that the mean of product with respect to Usage.
# - ### Here KP781 has highest mean value.

# %% [markdown]
# # Fitness vs Income

# %%
plt.figure(figsize=(13,7))
sns.lmplot(data=df, x = 'Fitness', y = 'Income')
plt.show()

# %% [markdown]
# - ### From the above plot, it is derived that the fitness with respect to income.
# - ### by this the value of fitness increase with respect to income.

# %% [markdown]
# # Education vs Income

# %%
plt.figure(figsize=(13,7))
sns.lmplot(data=df, x = 'Education', y = 'Income')
plt.show()

# %% [markdown]
# - ### From the above plot, it is derived that the Education with respect to income.
# - ### by this the value of Education increase with respect to income.

# %% [markdown]
# # Unit product price vs Usage

# %%
plt.figure(figsize=(13,7))
sns.lmplot(data=df1, x = 'Unit Product Price', y = 'Usage')
plt.show()

# %% [markdown]
# - ### From the above plot, it is derived that the Unit Product Price with respect to Usage.
# - ### by this the value of Unit Product Price increase with respect to Usage.

# %% [markdown]
# # Correlation of the data

# %%
df.corr()
# Out:
#                 Age  Education     Usage   Fitness    Income     Miles
# Age        1.000000   0.280496  0.015064  0.061105  0.513414  0.036618
# Education  0.280496   1.000000  0.395155  0.410581  0.625827  0.307284
# Usage      0.015064   0.395155  1.000000  0.668606  0.519537  0.759130
# Fitness    0.061105   0.410581  0.668606  1.000000  0.535005  0.785702
# Income     0.513414   0.625827  0.519537  0.535005  1.000000  0.543473
# Miles      0.036618   0.307284  0.759130  0.785702  0.543473  1.000000

# %%
sns.pairplot(data=df, hue='Product')
plt.show()

# %%
plt.figure(figsize=(13,7))
sns.heatmap(df.corr(), annot=True)
plt.show()

# %% [markdown]
# - ### From the above plot, it is derived that the correlation of the data.
# - ### Miles and Fitness and Miles and Usage are highly correlated, which means if a customer's fitness level is high they use more treadmills.
# - ### Income and education show a strong correlation. High-income and highly educated people prefer high-end models.
# - ### There is no corelation between Usage & Age or Fitness & Age which mean Age should not be barrier to use treadmills or specific model of treadmills.

# %% [markdown]
# # Findings
# - Total sales for KP281 treadmill of unit price $1500 is $120000
# - Total sales for KP481 treadmill of unit price $1750 is $105000
# - Total sales for KP781 treadmill of unit price $2500 is $100000
# - Age of customer using treadmill is between range 18 - 50.
# - The most bought treadmills are KP281 and the least bought treadmills are the KP781.
# - There are more male consumers than female.
# - There are more partnered consumers than single consumers.
# - KP281 and KP481 treadmills are bought by relatively similar number of male and female consumers.
# - A lot more males bought KP781 treadmills compared to the amount of females bought such.
# - The KP781 model was purchased more by customers of higher education.
# - Most customers who purchased a treadmill had completed 16 years of education.
# - Age distribution of both Males anf Females are almost the same.
# - Males have higher income than Females.
# - Education distribution of both Males anf Females are almost the same.
# - Males use treadmills more than Females.
# - Males seems to be more fit than Females.
# - Males seems to have ran more miles than Females.
# - Single people seems to be younger than Partnered people.
# - Partnered people seems to be earning more than Single people.
# - Partnered people seems to have ran more miles than single people

# %% [markdown]
# # Recommendations
# ### For the KP281 and KP481 treadmills,
# - years in education that is <= 16 (roughly until a college degree or less).
# - planned usage time of < 3-4 times a week
# - self-rated fitness of < 4 (poor to average shape)
# - an expected amount of < 125 walking / running miles.
# - generally low to average annual household income (< 60000)
#
# ### For KP781 treadmills,
# - years in education that is > 16.
# - planned usage time of > 4-5 times a week.
# - self-rated fitness of > 4 (good to excellent shape).
# - an expected amount of > 150 walking / running miles.
# - generally average to high annual household income (> 60000)
